# %% [markdown]
# # Data Preproccessing

# %%
 # importing neccessary libraries

# %%
import pandas as pd

# %%
# loading the dataset

# %%
df = pd.read_csv("UHI_d_NZFL.csv")

# %%
# understanding features

# %%
df.sample(5)
# Out:
#       sim_no     UHI_d  asphalt_ratio  park_grass_ratio  parcel_grass_ratio  \
# 2358    2358  0.133116       0.111386          0.072791            0.788921
# 4683    4683  0.151735       0.058153          0.075079            0.821947
# 2279    2279  0.120685       0.048316          0.093059            0.839920
# 8135    8135  0.178139       0.134203          0.083967            0.539732
# 6656    6656  0.232032       0.099550          0.088346            0.440574
#
#       podium_grass_ratio      GnPR       TCR  greenroof_ratio       SCR  ...  \
# 2358            0.000000  0.861712  0.072424         0.000000  0.026896  ...
# 4683            0.000000  0.897026  0.000000         0.044827  0.044827  ...
# 2279            0.000000  0.932979  0.059868         0.000000  0.018705  ...
# 8135            0.083766  0.707465  0.000000         0.139090  0.177574  ...
# 6656            0.158886  0.687806  0.000000         0.179598  0.245690  ...
#
#       avg_BH   avg_GPR  parcelArea  parkLocation  parkRadius  roadDensity  \
# 2358   102.2  1.294910           5             0         200          0.8
# 4683    85.0  1.548340           5             0         200          0.3
# 2279   108.4  0.855216           6            72         150          0.3
# 8135    21.7  1.013489           2            42         200          0.3
# 6656    33.5  1.685929           3            72         250          0.3
#
#       bldDensity  podiumDensity  treeDensity  roofType
# 2358           3            0.0            9         0
# 4683           5            0.0            0         1
# 2279           3            0.0            9         0
# 8135          11            0.2            9         1
# 6656          11            0.4            0         1
#
# [5 rows x 25 columns]

# %%
# removing the unnecessary columns

# %%
new_df = df[['GnPR',
    'treeDensity',
    'park_grass_ratio',
    'parcel_grass_ratio',
    'greenroof_ratio',
    'roadDensity',
    'bldDensity',
    'avg_BH',
    'avg_GPR','UHI_d']]

# %%
new_df
# Out:
#           GnPR  treeDensity  park_grass_ratio  parcel_grass_ratio  \
# 0     0.805629            0          0.034899            0.770730
# 1     0.851438            0          0.000000            0.851438
# 2     0.919077            0          0.000000            0.919077
# 3     0.910829            0          0.000000            0.910829
# 4     0.932979            0          0.079221            0.853758
# ...        ...          ...               ...                 ...
# 8995  0.613550            9          0.074712            0.359128
# 8996  0.645847            9          0.078687            0.425741
# 8997  0.604886            9          0.082933            0.367706
# 8998  0.637183            9          0.088649            0.423824
# 8999  0.697062            9          0.091245            0.446172
#
#       greenroof_ratio  roadDensity  bldDensity  avg_BH   avg_GPR     UHI_d
# 0            0.000000          0.3           3    73.1  1.738649  0.163756
# 1            0.000000          0.3           3    88.7  1.630876  0.158687
# 2            0.000000          0.3           3    99.2  1.390217  0.145582
# 3            0.000000          0.3           3   101.0  1.262646  0.139110
# 4            0.000000          0.3           3   105.4  0.846786  0.121279
# ...               ...          ...         ...     ...       ...       ...
# 8995         0.135745          0.8          11    22.1  1.059593  0.186005
# 8996         0.157678          0.8          11    35.3  1.695053  0.222568
# 8997         0.235218          0.8          11    48.8  2.281067  0.301918
# 8998         0.219515          0.8          11    60.5  2.391622  0.310068
# 8999         0.182033          0.8          11    72.7  2.663763  0.301872
#
# [9000 rows x 10 columns]

# %%
# identifying missing values

# %%
new_df.isnull().sum()
# Out:
# GnPR                  0
# treeDensity           0
# park_grass_ratio      0
# parcel_grass_ratio    0
# greenroof_ratio       0
# roadDensity           0
# bldDensity            0
# avg_BH                0
# avg_GPR               0
# UHI_d                 0
# dtype: int64

# %%
new_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9000 entries, 0 to 8999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   GnPR                9000 non-null   float64
#  1   treeDensity         9000 non-null   int64
#  2   park_grass_ratio    9000 non-null   float64
#  3   parcel_grass_ratio  9000 non-null   float64
#  4   greenroof_ratio     9000 non-null   float64
#  5   roadDensity         9000 non-null   float64
#  6   bldDensity          9000 non-null   int64
#  7   avg_BH              9000 non-null   float64
#  8   avg_GPR             9000 non-null   float64
#  9   UHI_d               9000 non-null   float64
# dtypes: float64(8), int64(2)
# memory usage: 703.3 KB

# %%
# identifying and removing duplicate values

# %%
new_df.duplicated().sum()
# Out:
# np.int64(2671)

# %%
print("Before:", new_df.shape)

new_df = new_df.drop_duplicates()

print("After:", new_df.shape)
# Out:
# Before: (9000, 10)
# After: (6329, 10)

# %%
new_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# identifying outliers using boxplot

# %%
import matplotlib.pyplot as plt

columns = [
    'GnPR',
    'treeDensity',
    'park_grass_ratio',
    'parcel_grass_ratio',
    'greenroof_ratio',
    'roadDensity',
    'bldDensity',
    'avg_BH',
    'avg_GPR'
]

# Create boxplots
for col in columns:
    plt.figure(figsize=(6,4))
    plt.boxplot(new_df[col])
    plt.title(f'Box Plot for {col}')
    plt.ylabel(col)
    plt.show()

# %%
# removing outliers in the independent features

# %%
# List of columns
columns = [
    'GnPR',
    'treeDensity',
    'park_grass_ratio',
    'parcel_grass_ratio',
    'greenroof_ratio',
    'roadDensity',
    'bldDensity',
    'avg_BH',
    'avg_GPR'
]

# Create copy to avoid modifying original dataset
df_clean = new_df.copy()

# Function to remove outliers using IQR
for col in columns:
    
    # Calculate Q1 and Q3
    Q1 = df_clean[col].quantile(0.25)
    Q3 = df_clean[col].quantile(0.75)
    
    # Calculate IQR
    IQR = Q3 - Q1
    
    # Define lower and upper bounds
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # Remove outliers
    df_clean = df_clean[
        (df_clean[col] >= lower_bound) & 
        (df_clean[col] <= upper_bound)
    ]

# Check shape before and after
print("Original shape:", new_df.shape)
print("Cleaned shape:", df_clean.shape)
# Out:
# Original shape: (6329, 10)
# Cleaned shape: (5767, 10)

# %%
# creating new preprocessed dataset

# %%
df_clean.to_csv("final_dataset.csv",index= False)

# %% [markdown]
# # Model Training

# %%
# Features (independent variables)
X = df_clean.drop("UHI_d", axis=1)

# Target (dependent variable)
y = df_clean["UHI_d"]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,      # 80% training, 20% testing
    random_state=42
)

# %%
# Import Linear Regression model from sklearn

# %%
from sklearn.linear_model import LinearRegression

# %%
# Create (initialize) the Linear Regression model object

# %%
lr_model = LinearRegression()

# %%
# Train the model using training data
# X_train → input features
# y_train → target values (temperature / UHI etc.)

# %%
lr_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Print the intercept of the regression line
# Print slope (coefficient) for each feature

# %%
print("Intercept:", lr_model.intercept_)
print("Slopes (Coefficients):", lr_model.coef_)
# Out:
# Intercept: 0.336834936852713
# Slopes (Coefficients): [-0.20760484  0.00030221 -0.27845217 -0.19758797 -0.00417347 -0.05925563
#   0.00660518  0.00119564  0.04227562]

# %%
y_pred = lr_model.predict(X_test)

# %%
# Create a DataFrame to clearly show feature names and their slopes
# Extract the slope (coefficient) specifically for greenery feature

# %%
import pandas as pd

coeff_df = pd.DataFrame({
    "Feature": X_train.columns,
    "Slope": lr_model.coef_
})

print(coeff_df)

# Correct feature selection
green_slope = coeff_df.loc[
    coeff_df["Feature"] == "GnPR",
    "Slope"
].values[0]

# Correct percentage conversion
temp_change_10_percent = green_slope * 0.10
# Out:
#               Feature     Slope
# 0                GnPR -0.207605
# 1         treeDensity  0.000302
# 2    park_grass_ratio -0.278452
# 3  parcel_grass_ratio -0.197588
# 4     greenroof_ratio -0.004173
# 5         roadDensity -0.059256
# 6          bldDensity  0.006605
# 7              avg_BH  0.001196
# 8             avg_GPR  0.042276

# %%
# Calculate temperature change for 10% increase in greenery

# %%
print(f"For every 10% increase in greenery, the temperature changes by {abs(temp_change_10_percent):.4f} °C")

if temp_change_10_percent < 0:
    print(f"This means temperature DECREASES by {abs(temp_change_10_percent):.4f} °C for every 10% increase in greenery.")
else:
    print(f"This means temperature INCREASES by {temp_change_10_percent:.4f} °C for every 10% increase in greenery.")
# Out:
# For every 10% increase in greenery, the temperature changes by 0.0208 °C
# This means temperature DECREASES by 0.0208 °C for every 10% increase in greenery.

# %% [markdown]
# # Model Evaluation

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print("MAE:", mae)
print("MSE:", mse)
print("RMSE:", rmse)
print("R2 Score:", r2)
# Out:
# MAE: 0.010306216829734089
# MSE: 0.00016999616610931248
# RMSE: 0.013038257786579941
# R2 Score: 0.9270207567181943

# %% [markdown]
# # Visualization and Graphs

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# Actual vs Predicted
plt.figure(figsize=(8,6))
plt.scatter(y_test, y_pred)
plt.plot([y_test.min(), y_test.max()],
         [y_test.min(), y_test.max()],
         color='red')
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Actual vs Predicted with Ideal Line")
plt.show()
